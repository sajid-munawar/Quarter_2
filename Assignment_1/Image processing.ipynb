# %% [markdown]
# # Image processing first practice

# %%
import PIL
print('Pillow Version:', PIL.__version__)
# Out:
# Pillow Version: 8.0.1

# %%
from PIL import Image

# %%
image=Image.open("nasir.jpg")

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x150 at 0x7F95D520D910>

# %%
image.size
# Out:
# (200, 150)

# %%
image.mode
# Out:
# 'RGB'

# %%
image.format
# Out:
# 'JPEG'

# %%
image.format_description
# Out:
# 'JPEG (ISO 10918)'

# %%
type(image)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
# converting image into numpy array

# %%
import numpy as np
img_arr=np.array(image)

# %%
img_arr.shape
# Out:
# (150, 200, 3)

# %%
img_arr.ravel().shape
# Out:
# (90000,)

# %% [markdown]
# ## load and display image with Matplotlib

# %%
from matplotlib import image
from matplotlib import pyplot

# %%
img=image.imread("nasir.jpg")

# %%
img2=image.imread("nasir.jpg")

# %%
img
# Out:
# array([[[ 24,  22,  72],
#         [ 24,  22,  72],
#         [ 24,  22,  72],
#         ...,
#         [116,  97,  83],
#         [113,  94,  80],
#         [108,  89,  75]],
#
#        [[ 24,  22,  72],
#         [ 24,  22,  72],
#         [ 24,  22,  72],
#         ...,
#         [115,  96,  82],
#         [114,  95,  81],
#         [111,  92,  78]],
#
#        [[ 24,  22,  72],
#         [ 24,  22,  72],
#         [ 24,  22,  72],
#         ...,
#         [114,  94,  83],
#         [114,  95,  81],
#         [114,  95,  81]],
#
#        ...,
#
#        [[ 55,  63,  99],
#         [ 56,  65,  98],
#         [ 57,  66,  97],
#         ...,
#         [241, 236, 214],
#         [234, 229, 207],
#         [220, 216, 191]],
#
#        [[ 59,  66,  95],
#         [ 59,  66,  94],
#         [ 60,  68,  91],
#         ...,
#         [246, 241, 219],
#         [243, 239, 214],
#         [233, 229, 204]],
#
#        [[ 61,  67,  91],
#         [ 63,  69,  91],
#         [ 64,  71,  90],
#         ...,
#         [251, 247, 222],
#         [253, 249, 224],
#         [251, 247, 222]]], dtype=uint8)

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
img.shape
# Out:
# (150, 200, 3)

# %%
# display the array of pixels as an image
pyplot.imshow(img)
pyplot.show()

# %%
pyplot.imshow(img2)
pyplot.show()

# %%
img3=np.vstack((img,img2))

# %%
pyplot.imshow(img3)

# %%
img3.shape
# Out:
# (300, 200, 3)

# %%
pyplot.imshow(img2.T.shape)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-f8ef89bb7276> in <module>
# ----> 1 pyplot.imshow(img2.T.shape)
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2722         filternorm=True, filterrad=4.0, resample=None, url=None,
#    2723         data=None, **kwargs):
# -> 2724     __ret = gca().imshow(
#    2725         X, cmap=cmap, norm=norm, aspect=aspect,
#    2726         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, **kwargs)
#    5521                               resample=resample, **kwargs)
#    5522
# -> 5523         im.set_data(X)
#    5524         im.set_alpha(alpha)
#    5525         if im.get_clip_path() is None:
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/image.py in set_data(self, A)
#     707         if not (self._A.ndim == 2
#     708                 or self._A.ndim == 3 and self._A.shape[-1] in [3, 4]):
# --> 709             raise TypeError("Invalid shape {} for image data"
#     710                             .format(self._A.shape))
#     711
#
# TypeError: Invalid shape (3,) for image data

# %% [markdown]
# ## manipulating and saving the image

# %%
import numpy as np
from PIL import Image

myImg = Image.open('nasir.jpg')
myImg = myImg.convert('L')
myImg = np.array(myImg)
#myImg = np.array(Image.open('kolala.jpeg').convert())

print(type(myImg))

gr_im= Image.fromarray(myImg).save('gr_nasir.png')
gr_im
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# study link: https://machinelearningmastery.com/how-to-load-and-manipulate-images-for-deep-learning-in-python-with-pil-pillow/

# %% [markdown]
# study link: https://www.geeksforgeeks.org/how-to-convert-images-to-numpy-array/
